# %%
from PIL import Image, ImageEnhance

im = Image.open('image.jpg')
obj = ImageEnhance.Brightness(im)
obj.enhance(factor=0.5)
# Out:
# <PIL.Image.Image image mode=RGB size=1100x735>

# %%
from PIL import Image, ImageEnhance

im = Image.open('image.jpg')
obj = ImageEnhance.Sharpness(im)
obj.enhance(factor=0.5)
# Out:
# <PIL.Image.Image image mode=RGB size=1100x735>
